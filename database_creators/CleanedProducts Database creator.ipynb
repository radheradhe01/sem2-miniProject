# %% [markdown]
# ## Imports

# %%
import weaviate
from weaviate.classes.config import DataType, Property, Configure

# %%
client = weaviate.connect_to_local()
print(client.is_ready())
# Out:
# True

# %% [markdown]
# ## The fields are
# id	gender	masterCategory	subCategory	articleType	baseColour	season	year	usage	productDisplayName	description	averageRating numberOfRatings	price

# %% [markdown]
# ## Defining the collection / class / schema

# %%
print(client.collections.exists("CleanedProducts"))
# Out:
# True

# %%
if client.collections.exists("CleanedProducts"):
    client.collections.delete("CleanedProducts")


client.collections.create(
    name="CleanedProducts",
    properties=[
        Property(name="productDisplayName", data_type=DataType.TEXT), 
        Property(name="season", data_type=DataType.TEXT),
        Property(name="description", data_type=DataType.TEXT),
        Property(name="gender", data_type=DataType.TEXT),
        Property(name="masterCategory", data_type=DataType.TEXT),
        Property(name="subCategory", data_type=DataType.TEXT),
        Property(name="price", data_type=DataType.TEXT),
        Property(name="numberOfRatings", data_type=DataType.INT),
        Property(name="averageRating", data_type=DataType.NUMBER),
        Property(name="productId", data_type=DataType.INT),
        Property(name="articleType", data_type=DataType.TEXT),
        Property(name="baseColour", data_type=DataType.TEXT),
        Property(name="year", data_type=DataType.INT),
        Property(name="usage", data_type=DataType.TEXT),
    ],
    vectorizer_config=[
        # Set a named vector
        Configure.NamedVectors.text2vec_transformers(  # Use the "text2vec-cohere" vectorizer
            name="name_master_sub_art_col_use_seas_gender", source_properties=["productDisplayName","masterCategory", "subCategory", "articleType", "baseColour", "usage", "season", 'gender']       # Set the source property(ies)
        ),
        # Configure.NamedVectors.text2vec_transformers(  # Use the "text2vec-openai" vectorizer
        #     name="name_master_sub_col", source_properties=["productDisplayName","masterCategory", "subCategory", "baseColour"] # Set the source property(ies)
        # ),
        # Configure.NamedVectors.text2vec_transformers(  # Use the "text2vec-openai" vectorizer
        #     name= "name_color_seas", source_properties=["productDisplayName", "baseColour", "season"] # Set the source property(ies)
        # ),
    ],
    
)

# %% [markdown]
# ## Importing and cleaning the data

# %%
import pandas as pd 

df = pd.read_csv(input("Enter the path to the csv file: "))

# include these fields id	gender	masterCategory	subCategory	articleType	baseColour	season	year	usage	productDisplayName	description	averageRating numberOfRatings	price
df = df[['productId', 'gender', 'masterCategory', 'subCategory', 'articleType', 'baseColour', 'season', 'year', 'usage', 'productDisplayName', 'description', 'averageRating', 'numberOfRatings', 'price']]

# print if na values are present
print(df.isna().sum())

# convert to dictionary
df_dict = df.to_dict(orient='records')
print(df_dict[:5])
# Out:
# productId             0
# gender                0
# masterCategory        0
# subCategory           0
# articleType           0
# baseColour            0
# season                0
# year                  0
# usage                 0
# productDisplayName    0
# description           0
# averageRating         0
# numberOfRatings       0
# price                 0
# dtype: int64
# [{'productId': 15970, 'gender': 'Men', 'masterCategory': 'Apparel', 'subCategory': 'Topwear', 'articleType': 'Shirts', 'baseColour': 'Navy Blue', 'season': 'Fall', 'year': 2011.0, 'usage': 'Casual', 'productDisplayName': 'Turtle Check Men Navy Blue Shirt', 'description': 'Turtle Check Men Navy Blue Shirt is a Navy Blue Shirts for Men in the Fall season.', 'averageRating': 3.2, 'numberOfRatings': 909, 'price': '₹ 999'}, {'productId': 39386, 'gender': 'Men', 'masterCategory': 'Apparel', 'subCategory': 'Bottomwear', 'articleType': 'Jeans', 'baseColour': 'Blue', 'season': 'Summer', 'year': 2012.0, 'usage': 'Casual', 'productDisplayName': 'Peter England Men Party Blue Jeans', 'description': 'Peter England Men Party Blue Jeans is a Blue Jeans for Men in the Summer season.', 'averageRating': 3.9, 'numberOfRatings': 613, 'price': '₹ 5999'}, {'productId': 59263, 'gender': 'Women', 'masterCategory': 'Accessories', 'subCategory': 'Watches', 'articleType': 'Watches', 'baseColour': 'Silver', 'season': 'Winter', 'year': 2016.0, 'usage': 'Casual', 'productDisplayName': 'Titan Women Silver Watch', 'description': 'Titan Women Silver Watch is a Silver Watches for Women in the Winter season.', 'averageRating': 3.4, 'numberOfRatings': 162, 'price': '₹ 7999'}, {'productId': 21379, 'gender': 'Men', 'masterCategory': 'Apparel', 'subCategory': 'Bottomwear', 'articleType': 'Track Pants', 'baseColour': 'Black', 'season': 'Fall', 'year': 2011.0, 'usage': 'Casual', 'productDisplayName': 'Manchester United Men Solid Black Track Pants', 'description': 'Manchester United Men Solid Black Track Pants is a Black Track Pants for Men in the Fall season.', 'averageRating': 3.2, 'numberOfRatings': 842, 'price': '₹ 3499'}, {'productId': 53759, 'gender': 'Men', 'masterCategory': 'Apparel', 'subCategory': 'Topwear', 'articleType': 'Tshirts', 'baseColour': 'Grey', 'season': 'Summer', 'year': 2012.0, 'usage': 'Casual', 'productDisplayName': 'Puma Men Grey T-shirt', 'description': 'Puma Men Grey T-shirt is a Grey Tshirts for Men in the Summer season.', 'averageRating': 2.7, 'numberOfRatings': 945, 'price': '₹ 4499'}]

# %%
collection = client.collections.get("CleanedProducts")

# %%
# write a function to insert data in batches of 1000, the dataset has about 31000 rows
def insert_data(data):
    try: 
        for i in range(0, len(data), 1000):
            print(f"Inserting data from {i} to {i+1000}")
            collection.data.insert_many(data[i:i+1000])
    except Exception as e:
        print(e)
    finally:
        print("Data Inserted Successfully!")

insert_data(df_dict)
# Out:
# Inserting data from 0 to 1000
# Inserting data from 1000 to 2000
# Inserting data from 2000 to 3000
# Inserting data from 3000 to 4000
# Inserting data from 4000 to 5000
# Inserting data from 5000 to 6000
# Inserting data from 6000 to 7000
# Inserting data from 7000 to 8000
# Inserting data from 8000 to 9000
# Inserting data from 9000 to 10000
# Inserting data from 10000 to 11000
# Inserting data from 11000 to 12000
# Inserting data from 12000 to 13000
# Inserting data from 13000 to 14000
# Inserting data from 14000 to 15000
# Inserting data from 15000 to 16000
# Inserting data from 16000 to 17000
# {'message': 'Failed to send 1 objects in a batch of 1000. Please inspect the errors variable of the returned object for more information.', 'errors': {583: ErrorObject(message="invalid integer property 'year' on class 'CleanedProducts': requires an integer, the given value is '2012.80649663463'", object_=BatchObject(collection='CleanedProducts', properties={'productId': 53781, 'gender': 'Men', 'masterCategory': 'Apparel', 'subCategory': 'Topwear', 'articleType': 'Tshirts', 'baseColour': 'Blue', 'season': 'Unknown', 'year': 2012.80649663463, 'usage': 'Sports', 'productDisplayName': 'Puma Men Blue Sless Round Neck T-shirt', 'description': 'Puma Men Blue Sless Round Neck T-shirt is a Blue Tshirts for Men in the Unknown season.', 'averageRating': 4.4, 'numberOfRatings': 506, 'price': '₹ 1499'}, references=None, uuid='f1fa36e7-97be-4da2-8b8b-a165c7fa3dcf', vector=None, tenant=None, index=583, retry_count=0), original_uuid='f1fa36e7-97be-4da2-8b8b-a165c7fa3dcf')}}
# Inserting data from 17000 to 18000
# Inserting data from 18000 to 19000
# Inserting data from 19000 to 20000
# Inserting data from 20000 to 21000
# Inserting data from 21000 to 22000
# Inserting data from 22000 to 23000
# Inserting data from 23000 to 24000
# Inserting data from 24000 to 25000
# Inserting data from 25000 to 26000
# Inserting data from 26000 to 27000
# Inserting data from 27000 to 28000
# Inserting data from 28000 to 29000
# Inserting data from 29000 to 30000
# Inserting data from 30000 to 31000
# Inserting data from 31000 to 32000
# Data Inserted Successfully!

# %%
from weaviate.classes.query import MetadataQuery

response = collection.query.near_text(
    query = "mujhe father ko kuch gift karna hai",
    limit = 100,
    target_vector = "name_master_sub_art_col_use_seas_gender",
    return_metadata=MetadataQuery(distance=True)
)

# %%
# Display the query results
print(f"Found {len(response.objects)} results")
for i, obj in enumerate(response.objects[:100]):
    print(f"\nResult {i+1}:")
    print(f"Product: {obj.properties['productDisplayName']}")
    print(f"Distance: {obj.metadata.distance}")
    print(f"Category: {obj.properties['masterCategory']} > {obj.properties['subCategory']} > {obj.properties['articleType']}")
    print(f"Price: {obj.properties['price']}")
# Out:
# Found 100 results
#
# Result 1:
# Product: Lino Perros Men Formal Pink Accessory Gift Set
# Distance: 0.6268256902694702
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 3999
#
# Result 2:
# Product: Lino Perros Men Formal Yellow Accessory Gift Set
# Distance: 0.6309895515441895
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 999
#
# Result 3:
# Product: Cabarelli Men Accessory Gift Set
# Distance: 0.632706880569458
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 1499
#
# Result 4:
# Product: Lino Perros Men Formal Red Accessory Gift Set
# Distance: 0.6333981156349182
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 7499
#
# Result 5:
# Product: Lino Perros Men Formal Blue Accessory Gift Set
# Distance: 0.6340821385383606
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 1999
#
# Result 6:
# Product: Lino Perros Men Formal Black Accessory Gift Set
# Distance: 0.6355754733085632
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 2999
#
# Result 7:
# Product: Lino Perros Men Formal Blue Red Accessory Gift Set
# Distance: 0.6358170509338379
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 7999
#
# Result 8:
# Product: Cabarelli Men Black Accessory Gift Set
# Distance: 0.6403758525848389
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 2999
#
# Result 9:
# Product: Lino Perros Men Formal Turquoise Blue Accessory Gift Set
# Distance: 0.6407090425491333
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 3499
#
# Result 10:
# Product: Lino Perros Men Formal Purple Accessory Gift Set
# Distance: 0.6421419382095337
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 5999
#
# Result 11:
# Product: Lino Perros Men Formal Maroon Accessory Gift Set
# Distance: 0.6431649923324585
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 249
#
# Result 12:
# Product: Lino Perros Men Formal Grey Accessory Gift Set
# Distance: 0.6448372602462769
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 7499
#
# Result 13:
# Product: Lino Perros Men Formal Brown Accessory Gift Set
# Distance: 0.6463767290115356
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 4499
#
# Result 14:
# Product: Cabarelli Men Brown Accessory Gift Set
# Distance: 0.646859347820282
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 7999
#
# Result 15:
# Product: Turtle Men Formal Red Accessory Gift Set
# Distance: 0.6483039259910583
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 3999
#
# Result 16:
# Product: Turtle Men Purple Accessory Gift Set
# Distance: 0.6505584120750427
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 5499
#
# Result 17:
# Product: Lino Perros Men Formal Navy Blue Accessory Gift Set
# Distance: 0.651509702205658
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 749
#
# Result 18:
# Product: Turtle Men Grey Accessory Gift Set
# Distance: 0.6555429100990295
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 7499
#
# Result 19:
# Product: Lino Perros Men Formal Navy Blue/Red Accessory Gift Set
# Distance: 0.6570174694061279
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 749
#
# Result 20:
# Product: Turtle Men Maroon Accessory Gift Set
# Distance: 0.6575102806091309
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 249
#
# Result 21:
# Product: Turtle Men Formal Maroon Accessory Gift Set
# Distance: 0.6595189571380615
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 1999
#
# Result 22:
# Product: Rasasi Men Skill Power Deo
# Distance: 0.6602586507797241
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 3499
#
# Result 23:
# Product: Rasasi Men Olympic Flame Deo
# Distance: 0.6608932614326477
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 3499
#
# Result 24:
# Product: Rasasi Men Dynamic Energy Deo
# Distance: 0.670355498790741
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 499
#
# Result 25:
# Product: Casio G-SHOCK GD-100WW-7DR
# Distance: 0.674587607383728
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 1999
#
# Result 26:
# Product: Arrow Men Formal Red Tie+Cufflink+Pocket square - Combo Pack
# Distance: 0.6829931735992432
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 5999
#
# Result 27:
# Product: Arrow Men Formal Purple Tie+Cufflink+Pocket square - Combo Pack
# Distance: 0.6839234828948975
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 249
#
# Result 28:
# Product: Arrow Men Formal Blue Tie+Cufflink+Pocket square - Combo Pack
# Distance: 0.6858307719230652
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 1499
#
# Result 29:
# Product: Reid & Taylor Men Formal Red Tie+Cufflink+Pocket square - Combo Pack
# Distance: 0.6897751092910767
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 7999
#
# Result 30:
# Product: Park Avenue Men Red Printed Broad Tie
# Distance: 0.6908223032951355
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 499
#
# Result 31:
# Product: IDEE Men Steel Sunglasses
# Distance: 0.6909984350204468
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 1999
#
# Result 32:
# Product: IDEE Men Black Sunglasses
# Distance: 0.6913003325462341
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 2499
#
# Result 33:
# Product: Hakashi Men Black Combo pack Tie+Cufflink+Pocket square
# Distance: 0.69137042760849
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 7499
#
# Result 34:
# Product: Q&Q Men Black Digital Watch
# Distance: 0.6918657422065735
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 6999
#
# Result 35:
# Product: Turtle Men Formal Blue Tie Cufflink & Pocket Square Set
# Distance: 0.6925623416900635
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 3499
#
# Result 36:
# Product: Titan Men Off White Dial Watch
# Distance: 0.6926674842834473
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 5499
#
# Result 37:
# Product: Arrow Men Formal Maroon Tie+Cufflink+Pocket square - Combo Pack
# Distance: 0.6927404403686523
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 749
#
# Result 38:
# Product: Reid & Taylor Men Formal Purple Tie+Cufflink+Pocket square - Combo Pack
# Distance: 0.6929436922073364
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 2499
#
# Result 39:
# Product: Reid & Taylor Men Formal Blue Tie+Cufflink+Pocket square - Combo Pack
# Distance: 0.6930721402168274
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 749
#
# Result 40:
# Product: Reid & Taylor Men Formal Blue  Tie+Cufflink+Pocket square - Combo Pack
# Distance: 0.6930721402168274
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 499
#
# Result 41:
# Product: Hakashi Men Combo pack Tie+Cufflink+Pocket square
# Distance: 0.6948109865188599
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 499
#
# Result 42:
# Product: Reid & Taylor Men Formal Black Tie+Cufflink+Pocket square - Combo Pack
# Distance: 0.6948287487030029
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 6499
#
# Result 43:
# Product: Park Avenue Men Blue Printed Tie
# Distance: 0.6963316798210144
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 5999
#
# Result 44:
# Product: ESPRIT Men Corso Silver Watch
# Distance: 0.6974836587905884
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 4999
#
# Result 45:
# Product: Reid & Taylor Men Formal Brown Tie+Cufflink+Pocket square - Combo Pack
# Distance: 0.698552131652832
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 1999
#
# Result 46:
# Product: IDEE Men Brown Sunglasses
# Distance: 0.6992800831794739
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 7999
#
# Result 47:
# Product: Carlos Moya Men Fragrances Gift Set
# Distance: 0.6999697685241699
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 999
#
# Result 48:
# Product: Q&Q Men Navy Blue Digital Watch
# Distance: 0.7005670666694641
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 499
#
# Result 49:
# Product: Pitaraa Women Bronze Clutch
# Distance: 0.704594612121582
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 2999
#
# Result 50:
# Product: Reid & Taylor Men Formal Maroon Tie+Cufflink+Pocket square - Combo Pack
# Distance: 0.7049825191497803
# Category: Accessories > Accessories > Accessory Gift Set
# Price: ₹ 6499
#
# Result 51:
# Product: Park Avenue Men Black Socks
# Distance: 0.7055888772010803
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 6499
#
# Result 52:
# Product: Ed Hardy Men Black & Green Dial Watch
# Distance: 0.707626223564148
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 6499
#
# Result 53:
# Product: Rasasi Women Body Lotion
# Distance: 0.7112206816673279
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 3999
#
# Result 54:
# Product: Ed Hardy Men Fragrance Gift Set
# Distance: 0.7114613056182861
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 499
#
# Result 55:
# Product: BOSS Men Boss Bottled Fragrance Gift Set
# Distance: 0.7116573452949524
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 1999
#
# Result 56:
# Product: Ed Hardy Love & Luck  Men Fragrance Gift Set
# Distance: 0.7124852538108826
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 6999
#
# Result 57:
# Product: Belkin Unisex Simple Messenger Blue Handbags
# Distance: 0.7136389017105103
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 6499
#
# Result 58:
# Product: BOSS Men Fragrance Gift Set
# Distance: 0.7138264179229736
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 499
#
# Result 59:
# Product: Police Passion Men Fragrance Gift Set
# Distance: 0.7169854044914246
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 249
#
# Result 60:
# Product: Park Avenue Red Patterned Tie
# Distance: 0.7173251509666443
# Category: Free Items > Free Gifts > Ties
# Price: ₹ 7499
#
# Result 61:
# Product: Image Women Black Sunglasses
# Distance: 0.7189984321594238
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 5499
#
# Result 62:
# Product: Lotus Herbals Moistpetals Royal Plum Lipstick 116
# Distance: 0.7202348113059998
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 3499
#
# Result 63:
# Product: Q&Q Men White Dial Watch
# Distance: 0.7215266227722168
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 1999
#
# Result 64:
# Product: Park Avenue Blue Patterned Tie
# Distance: 0.721792459487915
# Category: Free Items > Free Gifts > Ties
# Price: ₹ 499
#
# Result 65:
# Product: HUGO Men Fragrance Gift Set
# Distance: 0.7219926118850708
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 4999
#
# Result 66:
# Product: Murcia Women Maroon Satchel
# Distance: 0.7240486145019531
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 1499
#
# Result 67:
# Product: Nautica Voyage Men Fragrance Gift Set
# Distance: 0.7249770164489746
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 749
#
# Result 68:
# Product: Ed Hardy Love & Luck Women Mermaid Fragrance Gift Set
# Distance: 0.7256913185119629
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 4499
#
# Result 69:
# Product: Wills Lifestyle Men Leather Accessory Gift Set
# Distance: 0.7268354892730713
# Category: Accessories > Wallets > Wallets
# Price: ₹ 7499
#
# Result 70:
# Product: Tonino Lamborghini Forza For Men Fragrance Gift Set
# Distance: 0.7277071475982666
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 2999
#
# Result 71:
# Product: Police Dark Men Fragrance Gift Set
# Distance: 0.7291806936264038
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 3999
#
# Result 72:
# Product: Giordano Women White Dial Watch
# Distance: 0.7295715808868408
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 4499
#
# Result 73:
# Product: Reid & Taylor Men Maroon Checked Tie
# Distance: 0.7300988435745239
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 499
#
# Result 74:
# Product: Ed Hardy Women Spring Fragrance Gift Set
# Distance: 0.7330754399299622
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 7999
#
# Result 75:
# Product: Park Avenue Red Checked Tie
# Distance: 0.7330924272537231
# Category: Free Items > Free Gifts > Ties
# Price: ₹ 1249
#
# Result 76:
# Product: Police Cosmopolitian Men Fragrance Gift Set
# Distance: 0.7335801124572754
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 749
#
# Result 77:
# Product: Nike Fragrances Men Pure Fragrance Gift Set
# Distance: 0.7343735694885254
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 1999
#
# Result 78:
# Product: Nike Fragrances Men Urban Musk Fragrance Gift Set
# Distance: 0.7345547676086426
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 1499
#
# Result 79:
# Product: Nike Fragrances Men Ride Fragrance Gift Set
# Distance: 0.7359364032745361
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 7499
#
# Result 80:
# Product: Morellato Women White Dial Watch
# Distance: 0.7365190982818604
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 5499
#
# Result 81:
# Product: Tonino Lamborghini Mitico For Men Fragrance Gift Set
# Distance: 0.7369309663772583
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 2499
#
# Result 82:
# Product: Nike Fragrances Men Fragrance Gift Set
# Distance: 0.7371986508369446
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 7999
#
# Result 83:
# Product: Satya Paul Pink Saree
# Distance: 0.7398277521133423
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 5999
#
# Result 84:
# Product: Nike Women Pack of 3 Fragrance Gift Set
# Distance: 0.7399459481239319
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 5499
#
# Result 85:
# Product: Playboy Men New York Fragrance Gift Set
# Distance: 0.7406930923461914
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 4499
#
# Result 86:
# Product: Stoln Women White Sunglasses
# Distance: 0.7408314943313599
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 499
#
# Result 87:
# Product: Playboy Men Hollywood Fragrance Gift Set
# Distance: 0.7413973808288574
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 2499
#
# Result 88:
# Product: Valley of Flowers Women Fragrance Gift Set
# Distance: 0.7418864965438843
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 4999
#
# Result 89:
# Product: Park Avenue Black & Red Checked Tie
# Distance: 0.7420837879180908
# Category: Free Items > Free Gifts > Ties
# Price: ₹ 3499
#
# Result 90:
# Product: ADIDAS Women Natural Vitality Pack of 2 Fragrance Gift Set
# Distance: 0.7426814436912537
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 4499
#
# Result 91:
# Product: Aspen Women Black Dial Watch
# Distance: 0.7429788708686829
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 1249
#
# Result 92:
# Product: Satya Paul Green Saree
# Distance: 0.744830846786499
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 749
#
# Result 93:
# Product: Q&Q Unisex Blue Digital Watch
# Distance: 0.7452027797698975
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 5499
#
# Result 94:
# Product: Satya Paul Blue Saree
# Distance: 0.7453287839889526
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 3999
#
# Result 95:
# Product: Aspen Women Blue Dial Watch
# Distance: 0.745347261428833
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 5999
#
# Result 96:
# Product: Park Avenue Blue Paisley Pattern Tie
# Distance: 0.7459646463394165
# Category: Free Items > Free Gifts > Ties
# Price: ₹ 2499
#
# Result 97:
# Product: Nike Fragrances Men Blue Blue Wave Deo & Perfume
# Distance: 0.7460025548934937
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 5499
#
# Result 98:
# Product: Nike Fragrances Men Cool Wind Perfume and Deo Set
# Distance: 0.7465074062347412
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 5999
#
# Result 99:
# Product: Satya Paul Purple Saree
# Distance: 0.7465603351593018
# Category: Free Items > Free Gifts > Free Gifts
# Price: ₹ 2499
#
# Result 100:
# Product: Playboy Men Vegas Fragrance Gift Set
# Distance: 0.7466844916343689
# Category: Personal Care > Fragrance > Fragrance Gift Set
# Price: ₹ 1499
